# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dataclusterlabs/indian-number-plates-dataset")

print("Path to dataset files:", path)

# bad data

# %%
# !mv PATH_HERE ../data/input/

# %%
# !rm -rf PATH_HERE

# %%
# download new data

import kagglehub

# Download latest version
path = kagglehub.dataset_download("saisirishan/indian-vehicle-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/datasets/saisirishan/indian-vehicle-dataset

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !git clone https://github.com/Parthivendra/license-plate-detection.git
# Out:
# Cloning into 'license-plate-detection'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 91 (delta 0), reused 2 (delta 0), pack-reused 85 (from 2)
# Receiving objects: 100% (91/91), 166.81 MiB | 32.14 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /kaggle/working/license-plate-detection
# Out:
# /kaggle/working/license-plate-detection

# %%
# !mv data/input data/dataclusterlabs/indian-number-plates-dataset

# %%
# %mkdir data/input

# %%
# !ls data
# Out:
# dataclusterlabs  output

# %%
# !ls data
# Out:
# dataclusterlabs  input	output

# %%
# !git add .

# %%
# !git commit -m "chore: organise dataclusterlabs"
# Out:
# [main 3dc271a] chore: organise dataclusterlabs
#  27 files changed, 0 insertions(+), 0 deletions(-)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/1.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/10.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/11.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/12.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/13.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/14.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/15.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/16.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/17.jpg (100%)
#  rename data/{ => dataclusterlabs/indian-number-plates-dataset}/input/18.jpg (100%)
# ...

# %%
# !git config --global user.email "parthivendra2004@gmail.com"

# %%
# !git config --global user.name "Parthivendra Singh"

# %%
# !git push
# Out:
# Username for 'https://github.com': ^C
